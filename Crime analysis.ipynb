# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
crime_data=pd.read_csv("G:\Semester VI\INT247\Project\Indian-Crime-Data-master\Indian-Crime-Data-master\crime_data.csv")

# %%
crime_data
# Out:
#          States/UTs          District  Year  Murder  Attempt to commit Murder  \
# 0    Andhra Pradesh         Anantapur  2014     134                       171
# 1    Andhra Pradesh          Chittoor  2014      84                       170
# 2    Andhra Pradesh          Cuddapah  2014      80                       162
# 3    Andhra Pradesh     East Godavari  2014      64                        84
# 4    Andhra Pradesh  Guntakal Railway  2014      14                         4
# ..              ...               ...   ...     ...                       ...
# 796        Delhi UT         Vigilance  2014       0                         0
# 797        Delhi UT              West  2014      55                        77
# 798     Lakshadweep       Lakshadweep  2014       0                         0
# 799      Puducherry          Karaikal  2014       6                         1
# 800      Puducherry        Puducherry  2014      19                        14
#
# ...

# %%
crime_data["States/UTs"].value_counts()
# Out:
# Uttar Pradesh        76
# Madhya Pradesh       55
# Maharashtra          46
# Bihar                46
# Rajasthan            42
# Tamil Nadu           42
# Gujarat              41
# Karnataka            36
# Odisha               36
# Jammu & Kashmir      30
# West Bengal          30
# Assam                28
# Chhattisgarh         28
# Punjab               28
# Jharkhand            26
# Haryana              24
# Kerala               21
# Andhra Pradesh       20
# Arunachal Pradesh    19
# Delhi UT             19
# Himachal Pradesh     15
# Telangana            13
# Uttarakhand          13
# Meghalaya            11
# Nagaland             11
# Manipur              10
# Tripura               9
# Mizoram               9
# Sikkim                5
# Goa                   3
# A&N Islands           3
# Daman & Diu           2
# Puducherry            2
# Lakshadweep           1
# D&N Haveli            1
# Name: States/UTs, dtype: int64

# %%
crime_data['Year'].value_counts()
# Out:
# 2014    801
# Name: Year, dtype: int64
